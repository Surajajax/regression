# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('ParisHousing.csv')
data
# Out:
#       squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0            75523              3        0        1      63      9373
# 1            80771             39        1        1      98     39381
# 2            55712             58        0        1      19     34457
# 3            32316             47        0        0       6     27939
# 4            70429             19        1        1      90     38045
# ...            ...            ...      ...      ...     ...       ...
# 9994          1726             89        0        1       5     73133
# 9995         44403             29        1        1      12     34606
# 9996         83841              3        0        0      69     80933
# 9997         59036             70        0        0      96     55856
# 9998          1440             84        0        0      49     18412
#
#       cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0                 3              8  2005           0                  1
# 1                 8              6  2015           1                  0
# 2                 6              8  2021           0                  0
# 3                10              4  2012           0                  1
# 4                 3              7  1990           1                  0
# ...             ...            ...   ...         ...                ...
# 9994              7              6  2009           0                  1
# 9995              9              4  1990           0                  1
# 9996             10             10  2005           1                  1
# 9997              1              3  2010           0                  1
# 9998              6             10  1994           1                  0
#
#       basement  attic  garage  hasStorageRoom  hasGuestRoom      price
# 0         4313   9005     956               0             7  7559081.5
# 1         3653   2436     128               1             2  8085989.5
# 2         2937   8852     135               1             9  5574642.1
# 3          659   7141     359               0             3  3232561.2
# 4         8435   2429     292               1             4  7055052.0
# ...        ...    ...     ...             ...           ...        ...
# 9994      9311   1698     218               0             4   176425.9
# 9995      9061   1742     230               0             0  4448474.0
# 9996      8304   7730     345               1             9  8390030.5
# 9997      2590   6174     339               1             4  5905107.0
# 9998      8485   2024     278               1             6   146708.4
#
# [9999 rows x 17 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   squareMeters       9999 non-null   int64
#  1   numberOfRooms      9999 non-null   int64
#  2   hasYard            9999 non-null   int64
#  3   hasPool            9999 non-null   int64
#  4   floors             9999 non-null   int64
#  5   cityCode           9999 non-null   int64
#  6   cityPartRange      9999 non-null   int64
#  7   numPrevOwners      9999 non-null   int64
#  8   made               9999 non-null   int64
#  9   isNewBuilt         9999 non-null   int64
#  10  hasStormProtector  9999 non-null   int64
#  11  basement           9999 non-null   int64
#  12  attic              9999 non-null   int64
#  13  garage             9999 non-null   int64
#  14  hasStorageRoom     9999 non-null   int64
#  15  hasGuestRoom       9999 non-null   int64
#  16  price              9999 non-null   float64
# dtypes: float64(1), int64(16)
# memory usage: 1.3 MB

# %%
data.describe()
# Out:
#        squareMeters  numberOfRooms      hasYard      hasPool       floors  \
# count   9999.000000    9999.000000  9999.000000  9999.000000  9999.000000
# mean   49865.470747      50.356036     0.508651     0.496850    50.279228
# std    28772.039724      28.817167     0.499950     0.500015    28.889132
# min       89.000000       1.000000     0.000000     0.000000     1.000000
# 25%    25092.000000      25.000000     0.000000     0.000000    25.000000
# 50%    50102.000000      50.000000     1.000000     0.000000    50.000000
# 75%    74603.000000      75.000000     1.000000     1.000000    76.000000
# max    99999.000000     100.000000     1.000000     1.000000   100.000000
#
#            cityCode  cityPartRange  numPrevOwners         made   isNewBuilt  \
# count   9999.000000    9999.000000    9999.000000  9999.000000  9999.000000
# mean   50221.305331       5.510251       5.522052  2005.487949     0.499050
# std    29005.113181       2.872128       2.856593     9.308392     0.500024
# min        3.000000       1.000000       1.000000  1990.000000     0.000000
# 25%    24684.500000       3.000000       3.000000  1997.000000     0.000000
# 50%    50693.000000       5.000000       5.000000  2005.000000     0.000000
# 75%    75669.500000       8.000000       8.000000  2014.000000     1.000000
# max    99953.000000      10.000000      10.000000  2021.000000     1.000000
#
#        hasStormProtector      basement         attic       garage  \
# count        9999.000000   9999.000000   9999.000000  9999.000000
# mean            0.499850   5033.065807   5028.396240   553.104910
# std             0.500025   2876.870884   2894.220015   262.058211
# min             0.000000      0.000000      1.000000   100.000000
# 25%             0.000000   2559.500000   2512.500000   327.500000
# 50%             0.000000   5092.000000   5046.000000   554.000000
# 75%             1.000000   7511.500000   7541.000000   777.500000
# max             1.000000  10000.000000  10000.000000  1000.000000
#
#        hasStorageRoom  hasGuestRoom         price
# count     9999.000000   9999.000000  9.999000e+03
# mean         0.502950      4.994199  4.992982e+06
# std          0.500016      3.176316  2.877191e+06
# min          0.000000      0.000000  1.031350e+04
# 25%          0.000000      2.000000  2.516269e+06
# 50%          1.000000      5.000000  5.015730e+06
# 75%          1.000000      8.000000  7.467153e+06
# max          1.000000     10.000000  1.000677e+07

# %%
x=data.squareMeters
y=data.price
table= pd.DataFrame({'squareMeters': x, 'price': y})
print(table)
# Out:
#       squareMeters      price
# 0            75523  7559081.5
# 1            80771  8085989.5
# 2            55712  5574642.1
# 3            32316  3232561.2
# 4            70429  7055052.0
# ...            ...        ...
# 9994          1726   176425.9
# 9995         44403  4448474.0
# 9996         83841  8390030.5
# 9997         59036  5905107.0
# 9998          1440   146708.4
#
# [9999 rows x 2 columns]

# %%
x_array=np.array(x)
y_array=np.array(y)
print(x_array)
print(y_array)
# Out:
# [75523 80771 55712 ... 83841 59036  1440]
# [7559081.5 8085989.5 5574642.1 ... 8390030.5 5905107.   146708.4]

# %%
import matplotlib.pyplot as plt
plt.scatter(x_array, y_array, marker='.',c='r')
plt.title("Housing Price")
plt.xlabel("SquareMeter")
plt.ylabel("Price")
plt.show()

# %%
def cost_model(x,y ,w, b):
    n=x_array.shape[0]
    pred_y=np.zeros(n)
    cost = 0
    
    
    for i in range(n):
        pred_y= w * x[i] + b
        cost = cost + (pred_y - y[i])**2
    total_cost = 1 / (2 * n) * cost
        
    return total_cost

# %%
def compute_gradient(x, y, w, b): 
    n = x_array.shape[0]    
    dj_dw = 0
    dj_db = 0
    
    for i in range(n):  
        pred_y = w * x[i] + b 
        dj_dw_i = (pred_y- y[i]) * x[i] 
        dj_db_i = pred_y - y[i] 
        dj_db += dj_db_i
        dj_dw += dj_dw_i 
    dj_dwe = dj_dw / n 
    dj_dbe = dj_db / n 
        
    return dj_dwe, dj_dbe

# %%
import math

# %%
def gradient_descent(x, y, w_in, b_in, alpha, num_iters, cost_function, gradient_function): 

    
    # An array to store cost J and w's at each iteration primarily for graphing later
    J_history = []
    p_history = []
    b = b_in
    w = w_in
    
    for i in range(num_iters):
        # Calculate the gradient and update the parameters using gradient_function
        dj_dwe, dj_dbe = gradient_function(x, y, w , b)     

        # Update Parameters using equation (3) above
        b = b - alpha * dj_dbe                            
        w = w - alpha * dj_dwe                            

        # Save cost J at each iteration
        if i<100000:      # prevent resource exhaustion 
            J_history.append( cost_function(x, y, w , b))
            p_history.append([w,b])
        # Print cost every at intervals 10 times or as many iterations if < 10
        if i% math.ceil(num_iters/10) == 0:
            print(f"Iteration {i:4}: Cost {J_history[-1]:0.2e} ",
                f"dj_dw: {float(dj_dwe): 0.3e}, dj_db: {float(dj_dbe): 0.3e}  ",
                f"w: {w: 0.3e}, b: {b: 0.5e}")


 
    return w, b, J_history, p_history #return w and J,w history for graphing

# %%
# initialize parameters
w_init = 0
b_init = 0
# some gradient descent settings
iterations = 10000
tmp_alpha = 0.01

# Feature scaling (min-max or z-score)
x_scaled = (x_array - x_array.mean()) / x_array.std()
y_scaled = (y_array - y_array.mean()) / y_array.std()

# run gradient descent
w_final, b_final, J_hist, p_hist = gradient_descent(x_scaled,y_scaled, w_init, b_init, tmp_alpha, 
                                                    iterations, cost_model, compute_gradient)
print(f"(w,b) found by gradient descent: ({w_final:8.4f},{b_final:8.4f})")
# Out:
# Iteration    0: Cost 4.90e-01  dj_dw: -1.000e+00, dj_db:  1.752e-17   w:  1.000e-02, b: -1.75211e-19
# Iteration 1000: Cost 6.44e-07  dj_dw: -4.317e-05, dj_db: -2.389e-18   w:  1.000e+00, b:  4.11170e-17
# Iteration 2000: Cost 6.43e-07  dj_dw: -1.864e-09, dj_db: -2.214e-19   w:  1.000e+00, b:  4.39293e-17
# Iteration 3000: Cost 6.43e-07  dj_dw: -8.046e-14, dj_db:  8.539e-19   w:  1.000e+00, b:  4.53540e-17
# Iteration 4000: Cost 6.43e-07  dj_dw: -5.521e-15, dj_db: -4.021e-19   w:  1.000e+00, b:  5.02825e-17
# Iteration 5000: Cost 6.43e-07  dj_dw: -5.521e-15, dj_db: -2.023e-19   w:  1.000e+00, b:  5.31603e-17
# Iteration 6000: Cost 6.43e-07  dj_dw: -5.521e-15, dj_db: -1.579e-19   w:  1.000e+00, b:  5.49378e-17
# Iteration 7000: Cost 6.43e-07  dj_dw: -5.521e-15, dj_db: -1.579e-19   w:  1.000e+00, b:  5.52513e-17
# Iteration 8000: Cost 6.43e-07  dj_dw: -5.521e-15, dj_db: -1.579e-19   w:  1.000e+00, b:  5.52485e-17
# Iteration 9000: Cost 6.43e-07  dj_dw: -5.521e-15, dj_db: -1.579e-19   w:  1.000e+00, b:  5.52458e-17
# (w,b) found by gradient descent: (  1.0000,  0.0000)
